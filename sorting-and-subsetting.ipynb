# %% [markdown]
# # Sorting and subsetting DataFrames

# %%
import pandas as pd

df = pd.read_csv("./datasets/data-penumpang-bus-transjakarta-november-2021.csv")
df.head()
# Out:
#    tahun  bulan       jenis kode_trayek                                trayek  \
# 0   2021     11  Mikrotrans      JAK.88  Terminal Tanjung Priok - Ancol Barat
# 1   2021     11  Mikrotrans      JAK.85              Bintara - Cipinang Indah
# 2   2021     11  Mikrotrans      JAK.84  Terminal Kampung Melayu - Kapin Raya
# 3   2021     11  Mikrotrans      JAK.80             Rawa Buaya - Rawa Kompeni
# 4   2021     11  Mikrotrans       JA.77         Tanjung Priok - Jembatan Item
#
#    jumlah_penumpang
# 0             40135
# 1             38487
# 2             49142
# 3             66701
# 4             75248

# %% [markdown]
# ## Sorting
#
# Sorting a DataFrame is useful for organizing the data in a specific order, such as ascending or descending order, based on one or more columns. This can make it easier to analyze the data and identify patterns or trends. Additionally, subsetting a dataframe allows you to extract specific rows or columns of data based on certain conditions, which can be useful for further analysis or visualization.

# %% [markdown]
# ### Sorting by a single column
#
# To sort a DataFrame by a single column, use the `sort_values()` method. The `sort_values()` method takes the name of the column to sort by as a string, and the `ascending` argument to specify whether to sort in ascending or descending order. By default, `ascending=True`, which sorts in ascending order.

# %%
df.sort_values(by="jumlah_penumpang", ascending=True)
# Out:
#      tahun  bulan                    jenis kode_trayek  \
# 91    2021     11  Angkutan Umum Integrasi          8C
# 96    2021     11  Angkutan Umum Integrasi          6R
# 117   2021     11  Angkutan Umum Integrasi          1F
# 128   2021     11  Angkutan Umum Integrasi         GR5
# 127   2021     11  Angkutan Umum Integrasi         GR4
# ..     ...    ...                      ...         ...
# 76    2021     11                      BRT           5
# 73    2021     11                      BRT           8
# 78    2021     11                      BRT           3
# 72    2021     11                      BRT           9
# 84    2021     11                      BRT           1
#
#                                   trayek  jumlah_penumpang
# 91          Kebayoran Lama - Tanah Abang                 0
# 96        Ragunan - Stasin MRT Fatmawati                 0
# 117  Stasiun Palmerah - Bundaran Senayan                 0
# 128                    Kota Tua Explorer                 3
# 127     Taman Kota Intan - Museum Bahari                 4
# ..                                   ...               ...
# 76                Kampung Melayu - Ancol            487576
# 73                 Lebak Bulus - Harmoni            512842
# 78                Kalideres - Pasar Baru            527539
# 72                  Pinang Ranti - Pluit            805724
# 84                         Blok M - Kota           1073929
#
# [129 rows x 6 columns]

# %% [markdown]
# to get a spesific number of rows, use `head()` or `tail()` method.

# %% [markdown]
# this `head()` method will return the first specified number of rows (default is 5)

# %%
df.sort_values(by="jumlah_penumpang", ascending=True).head(10)
# Out:
#      tahun  bulan                    jenis kode_trayek  \
# 91    2021     11  Angkutan Umum Integrasi          8C
# 96    2021     11  Angkutan Umum Integrasi          6R
# 117   2021     11  Angkutan Umum Integrasi          1F
# 128   2021     11  Angkutan Umum Integrasi         GR5
# 127   2021     11  Angkutan Umum Integrasi         GR4
# 97    2021     11  Angkutan Umum Integrasi          6Q
# 107   2021     11  Angkutan Umum Integrasi          3E
# 122   2021     11  Angkutan Umum Integrasi         12A
# 60    2021     11               Mikrotrans     JAK.10B
# 110   2021     11  Angkutan Umum Integrasi          2P
#
#                                           trayek  jumlah_penumpang
# 91                  Kebayoran Lama - Tanah Abang                 0
# 96                Ragunan - Stasin MRT Fatmawati                 0
# 117          Stasiun Palmerah - Bundaran Senayan                 0
# 128                            Kota Tua Explorer                 3
# 127             Taman Kota Intan - Museum Bahari                 4
# 97   Dukuh Atas - Casablanca via Epicentrum Raya               608
# 107       Sentraland Cengkareng - Puri Kembangan               901
# 122                    Pelabuhan Kaliadem - Kota              1463
# 60           Gondangdia - Cikini via Kramat Raya              4008
# 110                           Gondangdia - Senen              4653

# %% [markdown]
# this `tail()` method will return the last specified number of rows (default is 5)

# %%
df.sort_values(by="jumlah_penumpang", ascending=True).tail(10)
# Out:
#     tahun  bulan jenis kode_trayek                             trayek  \
# 77   2021     11   BRT           4             Pulo Gadung 2 - Tosari
# 79   2021     11   BRT           2            Pulo Gadung 1 - Harmoni
# 74   2021     11   BRT           7  Kampung Rambutan - Kampung Melayu
# 83   2021     11   BRT          10              Tanjung Priok - PGC 2
# 75   2021     11   BRT           6             Ragunan - Dukuh Atas 2
# 76   2021     11   BRT           5             Kampung Melayu - Ancol
# 73   2021     11   BRT           8              Lebak Bulus - Harmoni
# 78   2021     11   BRT           3             Kalideres - Pasar Baru
# 72   2021     11   BRT           9               Pinang Ranti - Pluit
# 84   2021     11   BRT           1                      Blok M - Kota
#
#     jumlah_penumpang
# 77            321515
# 79            374586
# 74            420738
# 83            421487
# 75            435539
# 76            487576
# 73            512842
# 78            527539
# 72            805724
# 84           1073929

# %% [markdown]
# ### Sorting by multiple columns
#
# We can also sort by multiple columns. To do this, pass a list of column names to the `sort_values()` method. The DataFrame will first be sorted by the first column name in the list, then by the second column name, and so on.

# %%
df.sort_values(["kode_trayek", "jumlah_penumpang"], ascending=[True, True]).head(10)
# Out:
#      tahun  bulan                    jenis kode_trayek  \
# 84    2021     11                      BRT           1
# 83    2021     11                      BRT          10
# 126   2021     11  Angkutan Umum Integrasi         10K
# 82    2021     11                      BRT          11
# 125   2021     11  Angkutan Umum Integrasi         11D
# 124   2021     11  Angkutan Umum Integrasi         11Q
# 81    2021     11                      BRT          12
# 122   2021     11  Angkutan Umum Integrasi         12A
# 123   2021     11  Angkutan Umum Integrasi         12B
# 80    2021     11                      BRT          13
#
#                                    trayek  jumlah_penumpang
# 84                          Blok M - Kota           1073929
# 83                  Tanjung Priok - PGC 2            421487
# 126  Tanjung Priok - Senen via Taman  BMW             34498
# 82           Pulo Gebang - Kampung Melayu            148930
# 125   Pulo Gebang - Pulo Gadung 2 via PIK             59155
# 124  Kampung Melayu - Pulo Gebang via BKT             11353
# 81   Penjaringan - Sunter Bouleverd Barat            163317
# 122             Pelabuhan Kaliadem - Kota              1463
# 123                         Pluit - Senen             10187
# 80                      Ciledug - Tendean            305567

# %% [markdown]
# ## Subsetting
#
# Subsetting a DataFrame allows you to extract specific rows or columns of data based on certain conditions, which can be useful for further analysis or visualization.

# %% [markdown]
# ### Subsetting Columns
#
# To subset columns, pass a list of column names to the DataFrame. This will return a new DataFrame with only the specified columns.

# %%
df["jumlah_penumpang"]
# Out:
# 0      40135
# 1      38487
# 2      49142
# 3      66701
# 4      75248
#        ...
# 124    11353
# 125    59155
# 126    34498
# 127        4
# 128        3
# Name: jumlah_penumpang, Length: 129, dtype: int64

# %% [markdown]
# or to get multiple columns:

# %%
df[["jumlah_penumpang", "kode_trayek"]]
# Out:
#      jumlah_penumpang kode_trayek
# 0               40135      JAK.88
# 1               38487      JAK.85
# 2               49142      JAK.84
# 3               66701      JAK.80
# 4               75248       JA.77
# ..                ...         ...
# 124             11353         11Q
# 125             59155         11D
# 126             34498         10K
# 127                 4         GR4
# 128                 3         GR5
#
# [129 rows x 2 columns]

# %% [markdown]
# ### Subsetting Rows
#
# #### Subsetting based on boolean condition
#
# To subset rows, pass a list of boolean values to the DataFrame. This will return a new DataFrame with only the rows that correspond to `True` in the list of boolean values.

# %%
df[df["jumlah_penumpang"] > 200000]
# Out:
#     tahun  bulan jenis kode_trayek                             trayek  \
# 72   2021     11   BRT           9               Pinang Ranti - Pluit
# 73   2021     11   BRT           8              Lebak Bulus - Harmoni
# 74   2021     11   BRT           7  Kampung Rambutan - Kampung Melayu
# 75   2021     11   BRT           6             Ragunan - Dukuh Atas 2
# 76   2021     11   BRT           5             Kampung Melayu - Ancol
# 77   2021     11   BRT           4             Pulo Gadung 2 - Tosari
# 78   2021     11   BRT           3             Kalideres - Pasar Baru
# 79   2021     11   BRT           2            Pulo Gadung 1 - Harmoni
# 80   2021     11   BRT          13                  Ciledug - Tendean
# 83   2021     11   BRT          10              Tanjung Priok - PGC 2
# 84   2021     11   BRT           1                      Blok M - Kota
#
#     jumlah_penumpang
# 72            805724
# 73            512842
# 74            420738
# 75            435539
# 76            487576
# 77            321515
# 78            527539
# 79            374586
# 80            305567
# 83            421487
# 84           1073929

# %% [markdown]
# #### Subsetting based on text data

# %%
df[df["trayek"].str.contains("Lebak Bulus")]
# Out:
#      tahun  bulan                    jenis kode_trayek  \
# 21    2021     11               Mikrotrans      JAK.49
# 24    2021     11               Mikrotrans      JAK.45
# 37    2021     11               Mikrotrans      JAK.32
# 69    2021     11               Mikrotrans      JAK.03
# 73    2021     11                      BRT           8
# 95    2021     11  Angkutan Umum Integrasi          7A
# 100   2021     11  Angkutan Umum Integrasi          6H
#
#                              trayek  jumlah_penumpang
# 21            Lebak Bulus - Cipulir             50611
# 24            Lebak Bulus - Ragunan             55555
# 37         Lebak Bulus - Petukangan             90627
# 69             Lebak Bulus - Andara             41216
# 73            Lebak Bulus - Harmoni            512842
# 95   Kampung Rambutan - Lebak Bulus             88324
# 100             Senen - Lebak Bulus             24583

# %% [markdown]
# #### Subsetting based on multiple conditions
#
# To subset rows based on multiple conditions, use the `&` and `|` operators. The `&` operator means "and", and the `|` operator means "or".

# %%
condition1 = df["trayek"].str.contains("Lebak Bulus")
condition2 = df["jumlah_penumpang"] > 70000
df[condition1 & condition2]
# Out:
#     tahun  bulan                    jenis kode_trayek  \
# 37   2021     11               Mikrotrans      JAK.32
# 73   2021     11                      BRT           8
# 95   2021     11  Angkutan Umum Integrasi          7A
#
#                             trayek  jumlah_penumpang
# 37        Lebak Bulus - Petukangan             90627
# 73           Lebak Bulus - Harmoni            512842
# 95  Kampung Rambutan - Lebak Bulus             88324
