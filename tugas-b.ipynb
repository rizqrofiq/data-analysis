# %%
from pandas import DataFrame
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./dataset/loan_approval_dataset.csv")
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 17.8+ KB

# %%
loan_status_index = [' loan_status']
loan_status_df = df [[' loan_status']]
loan_status_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    loan_status  4269 non-null   object
# dtypes: object(1)
# memory usage: 33.5+ KB

# %%
loan_status_df.isnull().values.any()
loan_status_df.isnull().sum()
# Out:
#  loan_status    0
# dtype: int64

# %%
df[" loan_status"].value_counts()
# Out:
#  loan_status
#  Approved    2656
#  Rejected    1613
# Name: count, dtype: int64

# %%
df_attribute = df.drop(loan_status_df, axis = 1)
df_attribute.info()
df_attribute.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
# dtypes: int64(10), object(2)
# memory usage: 400.3+ KB
# (4269, 12)

# %%
df_attribute.isnull().values.any()
df_attribute.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
# dtype: int64

# %%
kategori_df = df.select_dtypes(include=['object'])
kategori_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0    education      4269 non-null   object
#  1    self_employed  4269 non-null   object
#  2    loan_status    4269 non-null   object
# dtypes: object(3)
# memory usage: 100.2+ KB

# %%
numerik_df = df.select_dtypes(include=['int64'])
numerik_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    income_annum              4269 non-null   int64
#  3    loan_amount               4269 non-null   int64
#  4    loan_term                 4269 non-null   int64
#  5    cibil_score               4269 non-null   int64
#  6    residential_assets_value  4269 non-null   int64
#  7    commercial_assets_value   4269 non-null   int64
#  8    luxury_assets_value       4269 non-null   int64
#  9    bank_asset_value          4269 non-null   int64
# dtypes: int64(10)
# memory usage: 333.6 KB

# %%
numerik_index = numerik_df.columns
numerik_index
# Out:
# Index(['loan_id', ' no_of_dependents', ' income_annum', ' loan_amount',
#        ' loan_term', ' cibil_score', ' residential_assets_value',
#        ' commercial_assets_value', ' luxury_assets_value',
#        ' bank_asset_value'],
#       dtype='object')

# %%
import matplotlib
import matplotlib.pyplot as plt
df.hist(column=numerik_index, figsize=(15,50), layout=(15,1))
plt.show()

# %%
import seaborn as sns
# uji antara dependent dengan Umur
fig = plt.figure(figsize=(10,10))
sns.boxplot(x=" loan_status", y=" loan_term", data=df)
plt.show()

# %%
df[[' loan_status', ' loan_term']].groupby([' loan_status'], as_index=False).mean().sort_values(by=' loan_term', ascending=False)
# Out:
#    loan_status   loan_term
# 1     Rejected   11.728456
# 0     Approved   10.397590

# %%
import random
from scipy.stats import ttest_ind, ttest_rel
from scipy import stats

df = df[(np.abs(stats.zscore(df[" loan_status"])) < 3)]

term_0 = df[df[' loan_status'] == "Approved"][' loan_term']
term_1 = df[df[' loan_status'] == "Rejected"][' loan_term']


term_0 = term_0.values.tolist()
term_0 = random.sample(term_0, 10)
term_1 = term_1.values.tolist()
term_1 = random.sample(term_1, 10)

ttest, pval = ttest_ind(term_1, term_0, equal_var=False)
print("ttest", ttest)
print('p value', pval)

if pval < 0.05:
    print("Ho Ditolak")
else:
    print("Ho Diterima")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       2 from scipy.stats import ttest_ind, ttest_rel
#       3 from scipy import stats
# ----> 5 df = df[(np.abs(stats.zscore(df[" loan_status"])) < 3)]
#       7 term_0 = df[df[' loan_status'] == "Approved"][' loan_term']
#       8 term_1 = df[df[' loan_status'] == "Rejected"][' loan_term']
#
# File ~/Documents/College/Data Science/src/.venv/lib/python3.11/site-packages/scipy/stats/_stats_py.py:2973, in zscore(a, axis, ddof, nan_policy)
#    2891 def zscore(a, axis=0, ddof=0, nan_policy='propagate'):
#    2892     """
#    2893     Compute the z score.
#    2894
#    (...)
#    2971            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2972     """
# -> 2973     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#
# ...

# %%
import random
from scipy.stats import ttest_ind
from scipy import stats

df = df[(np.abs(stats.zscore(df["Active"])) < 3)]

income_1 = df[df['Deaths'] == 1]['Active']
income_0 = df[df['Deaths'] == 2]['Active']

income_0 = income_0.values.tolist()

if len(income_0) >= 10:
    income_0 = random.sample(income_0, 10)
else:
    income_0 = income_0

income_1 = income_1.values.tolist()

if len(income_1) >= 10:
    income_1 = random.sample(income_1, 10)
else:
    income_1 = income_1

ttest, pval = ttest_ind(income_1, income_0, equal_var=False)
print("ttest", ttest)
print('p value', pval)

if pval < 0.05 or np.isnan(pval):
    print("H0 ditolak")
else:
    print("H0 diterima")
# Out:
# ttest nan
# p value nan
# H0 ditolak

# %%
# contigency table
c_t = pd.crosstab(df[' education'], df[' loan_status'], margins = False)
c_t
# Out:
#  loan_status    Approved   Rejected
#  education
#  Graduate           1339        805
#  Not Graduate       1317        808

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

stat, p, dof, expected = chi2_contingency(c_t)
print('dof=%d' % dof)
print('p_value', p)
print(expected)

# interpret test-statistic
prob = 0.99
critical = chi2.ppf(prob, dof)
print('probabilitas=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
  print('Dependent (tolak H0)')
else:
  print('Independent (terima H0)')
# Out:
# dof=1
# p_value 0.7720042291016309
# [[1333.91051769  810.08948231]
#  [1322.08948231  802.91051769]]
# probabilitas=0.990, critical=6.635, stat=0.084
# Independent (terima H0)

# %%
# df.drop(columns=["Date"], axis=1, inplace=True)

# Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
# Correlation with output variable
cor_target = abs(cor["Deaths"])
# Selecting highly correlated features
relevant_features = cor_target[cor_target>0.1]
relevant_features
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 5
#       3 # Using Pearson Correlation
#       4 plt.figure(figsize=(12,10))
# ----> 5 cor = df.corr()
#       6 sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
#       7 plt.show()
#
# File ~/Documents/College/Data Science/src/.venv/lib/python3.11/site-packages/pandas/core/frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Documents/College/Data Science/src/.venv/lib/python3.11/site-packages/pandas/core/frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# ...
